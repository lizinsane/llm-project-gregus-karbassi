# %% [markdown]
# # Swiss History RAG - Quick Start Notebook
#
# This notebook helps you experiment with different components of the RAG system.

# %% [markdown]
# ## 1. Setup and Configuration

# %%
import sys
sys.path.append('..')

from src.utils import load_config, ensure_directories
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Load configuration
config = load_config()
print("Configuration loaded successfully!")
print(f"App: {config['app']['title']}")

# %% [markdown]
# ## 2. Test PDF Processing (Phase 2)
#
# Uncomment and run after implementing Phase 2

# %%
# from src.ingestion.pdf_processor import PDFProcessor
# 
# processor = PDFProcessor()
# text = processor.extract_text("../data/raw/your_pdf.pdf")
# print(f"Extracted {len(text)} characters")

# %% [markdown]
# ## 3. Test Chunking

# %%
# from src.ingestion.chunker import TextChunker
# 
# chunker = TextChunker(chunk_size=1000, chunk_overlap=200)
# chunks = chunker.chunk_text(text)
# print(f"Created {len(chunks)} chunks")
# print(f"First chunk: {chunks[0][:200]}...")

# %% [markdown]
# ## 4. Test Embeddings (Phase 3)

# %%
# from src.retrieval.embeddings import get_embeddings
# 
# embeddings = get_embeddings(config)
# test_text = "Wilhelm Tell"
# embedding = embeddings.embed_query(test_text)
# print(f"Embedding dimension: {len(embedding)}")

# %% [markdown]
# ## 5. Test Vector Store

# %%
# from src.retrieval.vector_store import VectorStore
# 
# vector_store = VectorStore(config)
# # Add documents
# # Search
# results = vector_store.search("Wann wurde die Schweiz gegründet?")
# print(f"Found {len(results)} results")

# %% [markdown]
# ## 6. Test RAG Chain

# %%
# from src.retrieval.rag_chain import RAGChain
# 
# rag = RAGChain(config)
# response = rag.query("Wer war Wilhelm Tell?")
# print(response)

# %% [markdown]
# ## 7. Experiment with Different Parameters

# %%
# Test different chunk sizes
# Test different embedding models
# Test different retrieval strategies
